# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
# load cam 1 excels
path_fc = r'/home/merge/merge/data/fc72/edited_headers'

df_c1p1 = pd.read_excel(path_fc+'/cam1parab1'+'_filtered.xlsx', index_col=None, header=0)
df_c1p2 = pd.read_excel(path_fc+'/cam1parab2'+'_filtered.xlsx', index_col=None, header=0)
df_c1p3 = pd.read_excel(path_fc+'/cam1parab3'+'_filtered.xlsx', index_col=None, header=0)
df_c1p4 = pd.read_excel(path_fc+'/cam1parab4'+'_filtered.xlsx', index_col=None, header=0)
df_c1p5 = pd.read_excel(path_fc+'/cam1parab5'+'_filtered.xlsx', index_col=None, header=0)
df_c1p6 = pd.read_excel(path_fc+'/cam1parab6'+'_filtered.xlsx', index_col=None, header=0)
df_c1p7 = pd.read_excel(path_fc+'/cam1parab7'+'_filtered.xlsx', index_col=None, header=0)
df_c1p8 = pd.read_excel(path_fc+'/cam1parab8'+'_filtered.xlsx', index_col=None, header=0)
df_c1p9 = pd.read_excel(path_fc+'/cam1parab9'+'_filtered.xlsx', index_col=None, header=0)
df_c1p10 = pd.read_excel(path_fc+'/cam1parab10'+'_filtered.xlsx', index_col=None, header=0)
df_c1p11 = pd.read_excel(path_fc+'/cam1parab11'+'_filtered.xlsx', index_col=None, header=0)
df_c1p12 = pd.read_excel(path_fc+'/cam1parab12'+'_filtered.xlsx', index_col=None, header=0)
df_c1p13 = pd.read_excel(path_fc+'/cam1parab13'+'_filtered.xlsx', index_col=None, header=0)
df_c1p14 = pd.read_excel(path_fc+'/cam1parab14'+'_filtered.xlsx', index_col=None, header=0)
df_c1p15 = pd.read_excel(path_fc+'/cam1parab15'+'_filtered.xlsx', index_col=None, header=0)

# df_c1 = pd.concat([df_c1p1, df_c1p2, df_c1p3, df_c1p4, df_c1p5, df_c1p6, df_c1p7, 
#                    df_c1p8, df_c1p9, df_c1p10, df_c1p11, df_c1p12, df_c1p13, df_c1p14, df_c1p15],ignore_index=True)

# %%
##for clipping at a given time. will replace .Frame with .Time and add a time for each parab 
#dont really know why i did this tbh 
df_c1p1 = df_c1p1[(df_c1p1.Frame == 1).idxmax():] #returns first instance where Frame==1, and slices it starting there
df_c1p2 = df_c1p2[(df_c1p2.Frame == 1).idxmax():]
df_c1p3 = df_c1p3[(df_c1p3.Frame == 1).idxmax():]
df_c1p4 = df_c1p4[(df_c1p4.Frame == 1).idxmax():]
df_c1p5 = df_c1p5[(df_c1p5.Frame == 1).idxmax():]
df_c1p6 = df_c1p6[(df_c1p6.Frame == 1).idxmax():]
df_c1p7 = df_c1p7[(df_c1p7.Frame == 1).idxmax():]
df_c1p8 = df_c1p8[(df_c1p8.Frame == 1).idxmax():]
df_c1p9 = df_c1p9[(df_c1p9.Frame == 1).idxmax():]
df_c1p10 = df_c1p10[(df_c1p10.Frame == 1).idxmax():]
df_c1p11 = df_c1p11[(df_c1p11.Frame == 1).idxmax():]
df_c1p12 = df_c1p12[(df_c1p12.Frame == 1).idxmax():]
df_c1p13 = df_c1p13[(df_c1p13.Frame == 1).idxmax():]
df_c1p14 = df_c1p14[(df_c1p14.Frame == 1).idxmax():]
df_c1p15 = df_c1p15[(df_c1p15.Frame == 1).idxmax():]

# %%
#load cam2 frome xcels
path_fc = r'/home/merge/merge/data/fc72/edited_headers'

df_c2p1 = pd.read_excel(path_fc+'/cam2parab1'+'_filtered.xlsx', index_col=None, header=0)
df_c2p2 = pd.read_excel(path_fc+'/cam2parab2'+'_filtered.xlsx', index_col=None, header=0)
df_c2p3 = pd.read_excel(path_fc+'/cam2parab3'+'_filtered.xlsx', index_col=None, header=0)
df_c2p4 = pd.read_excel(path_fc+'/cam2parab4'+'_filtered.xlsx', index_col=None, header=0)
df_c2p5 = pd.read_excel(path_fc+'/cam2parab5'+'_filtered.xlsx', index_col=None, header=0)
df_c2p6 = pd.read_excel(path_fc+'/cam2parab6'+'_filtered.xlsx', index_col=None, header=0)
df_c2p7 = pd.read_excel(path_fc+'/cam2parab7'+'_filtered.xlsx', index_col=None, header=0)
df_c2p8 = pd.read_excel(path_fc+'/cam2parab8'+'_filtered.xlsx', index_col=None, header=0)
df_c2p9 = pd.read_excel(path_fc+'/cam2parab9'+'_filtered.xlsx', index_col=None, header=0)
df_c2p10 = pd.read_excel(path_fc+'/cam2parab10'+'_filtered.xlsx', index_col=None, header=0)
df_c2p11 = pd.read_excel(path_fc+'/cam2parab11'+'_filtered.xlsx', index_col=None, header=0)
df_c2p12 = pd.read_excel(path_fc+'/cam2parab12'+'_filtered.xlsx', index_col=None, header=0)
df_c2p13 = pd.read_excel(path_fc+'/cam2parab13'+'_filtered.xlsx', index_col=None, header=0)
df_c2p14 = pd.read_excel(path_fc+'/cam2parab14'+'_filtered.xlsx', index_col=None, header=0)
df_c2p15 = pd.read_excel(path_fc+'/cam2parab15'+'_filtered.xlsx', index_col=None, header=0)

# %%
df_c2p1 = df_c2p1[(df_c2p1.Frame == 1).idxmax():]
df_c2p2 = df_c2p2[(df_c2p2.Frame == 1).idxmax():]
df_c2p3 = df_c2p3[(df_c2p3.Frame == 1).idxmax():]
df_c2p4 = df_c2p4[(df_c2p4.Frame == 1).idxmax():]
df_c2p5 = df_c2p5[(df_c2p5.Frame == 1).idxmax():]
df_c2p6 = df_c2p6[(df_c2p6.Frame == 1).idxmax():]
df_c2p7 = df_c2p7[(df_c2p7.Frame == 1).idxmax():]
df_c2p8 = df_c2p8[(df_c2p8.Frame == 1).idxmax():]
df_c2p9 = df_c2p9[(df_c2p9.Frame == 1).idxmax():]
df_c2p10 = df_c2p10[(df_c2p10.Frame == 1).idxmax():]
df_c2p11 = df_c2p11[(df_c2p11.Frame == 1).idxmax():]
df_c2p12 = df_c2p12[(df_c2p12.Frame == 1).idxmax():]
df_c2p13 = df_c2p13[(df_c2p13.Frame == 1).idxmax():]
df_c2p14 = df_c2p14[(df_c2p14.Frame == 1).idxmax():]
df_c2p15 = df_c2p15[(df_c2p15.Frame == 1).idxmax():]

# %%
#load cam3 from excels
path_fc = r'/home/merge/merge/data/fc72/edited_headers'

df_c3p1 = pd.read_excel(path_fc+'/cam3parab1'+'_filtered.xlsx', index_col=None, header=0)
df_c3p2 = pd.read_excel(path_fc+'/cam3parab2'+'_filtered.xlsx', index_col=None, header=0)
df_c3p3 = pd.read_excel(path_fc+'/cam3parab3'+'_filtered.xlsx', index_col=None, header=0)
df_c3p4 = pd.read_excel(path_fc+'/cam3parab4'+'_filtered.xlsx', index_col=None, header=0)
df_c3p5 = pd.read_excel(path_fc+'/cam3parab5'+'_filtered.xlsx', index_col=None, header=0)
df_c3p6 = pd.read_excel(path_fc+'/cam3parab6'+'_filtered.xlsx', index_col=None, header=0)
df_c3p7 = pd.read_excel(path_fc+'/cam3parab7'+'_filtered.xlsx', index_col=None, header=0)
df_c3p8 = pd.read_excel(path_fc+'/cam3parab8'+'_filtered.xlsx', index_col=None, header=0)
df_c3p9 = pd.read_excel(path_fc+'/cam3parab9'+'_filtered.xlsx', index_col=None, header=0)
df_c3p10 = pd.read_excel(path_fc+'/cam3parab10'+'_filtered.xlsx', index_col=None, header=0)
df_c3p11 = pd.read_excel(path_fc+'/cam3parab11'+'_filtered.xlsx', index_col=None, header=0)
df_c3p12 = pd.read_excel(path_fc+'/cam3parab12'+'_filtered.xlsx', index_col=None, header=0)
df_c3p13 = pd.read_excel(path_fc+'/cam3parab13'+'_filtered.xlsx', index_col=None, header=0)
df_c3p14 = pd.read_excel(path_fc+'/cam3parab14'+'_filtered.xlsx', index_col=None, header=0)
df_c3p15 = pd.read_excel(path_fc+'/cam3parab15'+'_filtered.xlsx', index_col=None, header=0)

# %%
df_c3p1 = df_c3p1[(df_c3p1.Frame == 1).idxmax():]
df_c3p2 = df_c3p2[(df_c3p2.Frame == 1).idxmax():]
df_c3p3 = df_c3p3[(df_c3p3.Frame == 1).idxmax():]
df_c3p4 = df_c3p4[(df_c3p4.Frame == 1).idxmax():]
df_c3p5 = df_c3p5[(df_c3p5.Frame == 1).idxmax():]
df_c3p6 = df_c3p6[(df_c3p6.Frame == 1).idxmax():]
df_c3p7 = df_c3p7[(df_c3p7.Frame == 1).idxmax():]
df_c3p8 = df_c3p8[(df_c3p8.Frame == 1).idxmax():]
df_c3p9 = df_c3p9[(df_c3p9.Frame == 1).idxmax():]
df_c3p10 = df_c3p10[(df_c3p10.Frame == 1).idxmax():]
df_c3p11 = df_c3p11[(df_c3p11.Frame == 1).idxmax():]
df_c3p12 = df_c3p12[(df_c3p12.Frame == 1).idxmax():]
df_c3p13 = df_c3p13[(df_c3p13.Frame == 1).idxmax():]
df_c3p14 = df_c3p14[(df_c3p14.Frame == 1).idxmax():]
df_c3p15 = df_c3p15[(df_c3p15.Frame == 1).idxmax():]

# %%
#concatenate parabs so we have an array per cam
df_c1 = pd.concat([df_c1p1, df_c1p2, df_c1p3, df_c1p4, df_c1p5, df_c1p6, df_c1p7, 
                   df_c1p8, df_c1p9, df_c1p10, df_c1p11, df_c1p12, df_c1p13, df_c1p14, df_c1p15],ignore_index=True)


df_c2 = pd.concat([df_c2p1, df_c2p2, df_c2p3, df_c2p4, df_c2p5, df_c2p6, df_c2p7, 
                   df_c2p8, df_c2p9, df_c2p10, df_c2p11, df_c2p12, df_c2p13, df_c2p14, df_c2p15],ignore_index=True)


df_c3 = pd.concat([df_c3p1, df_c3p2, df_c3p3, df_c3p4, df_c3p5, df_c3p6, df_c3p7, 
                   df_c3p8, df_c3p9, df_c3p10, df_c3p11, df_c3p12, df_c3p13, df_c3p14, df_c3p15], ignore_index=True)

# %%
pd.set_option("display.max_columns", 50)
df_c1.head()
# Out:
#    Frame      Time  Slice1_Min  Slice1_Max  Slice2_Min  Slice2_Max  \
# 0    1.0  0.033333         0.0         0.0         0.0         0.0
# 1    2.0  0.066667         0.0         0.0         0.0         0.0
# 2    3.0  0.100000         0.0         0.0         0.0         0.0
# 3    4.0  0.133333         0.0         0.0         0.0         0.0
# 4    5.0  0.166667         0.0         0.0         0.0         0.0
#
#    Slice3_Min  Slice3_Max  Slice4_Min  Slice4_Max  Slice5_Min  Slice5_Max  \
# 0         0.0         0.0         0.0    4.969676         0.0    5.290829
# 1         0.0         0.0         0.0    6.294431         0.0    6.708161
# 2         0.0         0.0         0.0    7.344322         0.0    7.958773
# 3         0.0         0.0         0.0    8.394213         0.0    9.209384
# 4         0.0         0.0         0.0    8.676451         0.0    9.882822
#
#    Slice6_Min  Slice6_Max  Slice7_Min  Slice7_Max  Slice8_Min  Slice8_Max  \
# 0         0.0         0.0         0.0   14.721415         0.0   14.724692
# 1         0.0         0.0         0.0   15.465310         0.0   15.470225
# 2         0.0         0.0         0.0   15.764342         0.0   15.771716
# 3         0.0         0.0         0.0   16.063375         0.0   16.073206
# 4         0.0         0.0         0.0   16.067062         0.0   16.077712
#
#    Slice9_Min  Slice9_Max  Slice10_Min  Slice10_Max  Slice11_Min  Slice11_Max  \
# 0         0.0    9.205698          0.0     9.382659          0.0    11.616392
# 1         0.0    9.670632          0.0     9.893473          0.0    13.358154
# 2         0.0    9.205698          0.0    10.118771          0.0    12.877654
# 3         0.0    8.740763          0.0    10.344070          0.0    12.397154
# 4         0.0    8.647777          0.0    10.363732          0.0    11.844967
#
#    Slice12_Min  Slice12_Max  Slice13_Min  Slice13_Max  Slice14_Min  \
# 0          0.0    11.627862          0.0     6.615584          0.0
# 1          0.0    13.370443          0.0     6.615584          0.0
# 2          0.0    13.359793          0.0     5.350840          0.0
# 3          0.0    13.349142          0.0     4.086096          0.0
# 4          0.0    11.617211          0.0     3.988808          0.0
#
#    Slice14_Max  cam  parab
# 0     2.560210  1.0    1.0
# 1     3.060783  1.0    1.0
# 2     2.964929  1.0    1.0
# 3     2.869074  1.0    1.0
# 4     2.464356  1.0    1.0

# %%
#### This gives a lot of warnings, check this!!! -------------------------------------------<<
# adds the extra columns indicating how many slices above the cutoff
# Nab75 = Number of slices with heights above 75% of total chamber height
h = 16.192    #chamber height

df_list = [df_c1p1, df_c1p2, df_c1p3, df_c1p4, df_c1p5, df_c1p6, df_c1p7, df_c1p8, df_c1p9, df_c1p10,
         df_c1p11, df_c1p12, df_c1p13, df_c1p14, df_c1p15,
           df_c2p1, df_c2p2, df_c2p3, df_c2p4, df_c2p5, df_c2p6, df_c2p7, df_c2p8, df_c2p9, df_c2p10,
          df_c2p11, df_c2p12, df_c2p13, df_c2p14, df_c2p15,
           df_c3p1, df_c3p2, df_c3p3, df_c3p4, df_c3p5, df_c3p6, df_c3p7, df_c3p8, df_c3p9, df_c3p10,
          df_c3p11, df_c3p12, df_c3p13, df_c3p14, df_c3p15]

def addingNab(df):
    mask = df.columns.str.contains("Slice.*Max")
    df_masked = df.loc[:,mask]
    df["Nab25"] = df_masked.gt(0.25*h).sum(axis=1) 
    df["Nab50"] = df_masked.gt(0.50*h).sum(axis=1)
    df["Nab75"] = df_masked.gt(0.75*h).sum(axis=1)
    df["Nab95"] = df_masked.gt(0.95*h).sum(axis=1)
    return df

for df in df_list: 
    df = addingNab(df)
# Out:
# /tmp/ipykernel_3232/2642554465.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nab25"] = df_masked.gt(0.25*h).sum(axis=1)
# /tmp/ipykernel_3232/2642554465.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nab50"] = df_masked.gt(0.50*h).sum(axis=1)
# /tmp/ipykernel_3232/2642554465.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nab75"] = df_masked.gt(0.75*h).sum(axis=1)
# /tmp/ipykernel_3232/2642554465.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nab95"] = df_masked.gt(0.95*h).sum(axis=1)

# %%
df_c3p11
# Out:
#        Frame       Time  Slice1_Min  Slice1_Max  Slice2_Min  Slice2_Max  \
# 1        1.0   0.033333         0.0    9.918153         0.0    0.000000
# 2        2.0   0.066667         0.0    9.988508         0.0    0.000000
# 3        3.0   0.100000         0.0   10.128397         0.0    0.000000
# 4        4.0   0.133333         0.0   10.268287         0.0    0.000000
# 5        5.0   0.166667         0.0   10.381961         0.0    0.000000
# ...      ...        ...         ...         ...         ...         ...
# 996    996.0  33.200000         0.0   15.743041         0.0   14.232312
# 997    997.0  33.233333         0.0   15.743041         0.0   14.225758
# 998    998.0  33.266667         0.0   15.742222         0.0   14.234361
# 999    999.0  33.300000         0.0   15.741403         0.0   14.242963
# 1000  1000.0  33.333333         0.0   15.739355         0.0   14.250336
#
#       Slice3_Min  Slice3_Max  Slice4_Min  Slice4_Max  Slice5_Min  Slice5_Max  \
# 1            0.0    0.030723         0.0    0.000000         0.0    8.651463
# 2            0.0    0.031951         0.0    0.000000         0.0    9.949183
# 3            0.0    0.033180         0.0    0.000000         0.0   10.167927
# 4            0.0    0.034409         0.0    0.000000         0.0    9.949183
# 5            0.0    0.218744         0.0    0.000000         0.0    9.942629
# ...          ...         ...         ...         ...         ...         ...
# 996          0.0   15.782776         0.0   15.779089         0.0   15.900341
# 997          0.0   15.793017         0.0   15.790559         0.0   15.901979
# 998          0.0   15.803667         0.0   15.802029         0.0   15.914268
# 999          0.0   15.793017         0.0   15.790559         0.0   15.926557
# 1000         0.0   15.797523         0.0   15.793836         0.0   15.949906
#
#       Slice6_Min  Slice6_Max  Slice7_Min  Slice7_Max  Slice8_Min  Slice8_Max  \
# 1            0.0    9.196276         0.0   10.503417         0.0    5.935182
# 2            0.0    8.367997         0.0   11.033893         0.0    7.194806
# 3            0.0    7.888725         0.0   11.242806         0.0    8.200457
# 4            0.0    7.409454         0.0   11.451719         0.0    9.206107
# 5            0.0    6.674981         0.0   11.454177         0.0    9.897569
# ...          ...         ...         ...         ...         ...         ...
# 996          0.0   16.192000         0.0   16.192000         0.0   16.192000
# 997          0.0   16.192000         0.0   16.192000         0.0   16.192000
# 998          0.0   16.192000         0.0   16.192000         0.0   16.192000
# 999          0.0   16.192000         0.0   16.192000         0.0   16.192000
# 1000         0.0   16.192000         0.0   16.192000         0.0   16.192000
#
#       Slice9_Min  Slice9_Max  Slice10_Min  Slice10_Max  Slice11_Min  \
# 1            0.0    1.968699          0.0     4.249540          0.0
# 2            0.0    2.479103          0.0     4.620668          0.0
# 3            0.0    3.063650          0.0     4.753799          0.0
# 4            0.0    3.648198          0.0     4.886930          0.0
# 5            0.0    4.308117          0.0     5.301889          0.0
# ...          ...         ...          ...          ...          ...
# 996          0.0   16.192000          0.0    16.192000          0.0
# 997          0.0   16.192000          0.0    16.192000          0.0
# 998          0.0   16.192000          0.0    16.192000          0.0
# 999          0.0   16.192000          0.0    16.192000          0.0
# 1000         0.0   16.192000          0.0    16.192000          0.0
#
#       Slice11_Max  Slice12_Min  Slice12_Max  Slice13_Min  Slice13_Max  \
# 1        5.554633          0.0     6.083060          0.0     6.099445
# 2        5.964266          0.0     7.660150          0.0     7.684728
# 3        6.403394          0.0     9.011941          0.0     9.048808
# 4        6.842521          0.0    10.363732          0.0    10.412888
# 5        7.419695          0.0    11.039628          0.0    11.092880
# ...           ...          ...          ...          ...          ...
# 996     16.100652          0.0    16.067062          0.0    16.000701
# 997     16.105158          0.0    16.052725          0.0    15.984725
# 998     16.107615          0.0    16.048628          0.0    15.972436
# 999     16.110073          0.0    16.044532          0.0    15.960147
# 1000    16.098604          0.0    16.062965          0.0    15.953388
#
#       Slice14_Min  Slice14_Max  cam  parab  Nab25  Nab50  Nab75  Nab95
# 1             0.0     0.000000  3.0   11.0      9      4      0      0
# 2             0.0     0.000000  3.0   11.0      9      4      0      0
# 3             0.0     0.000000  3.0   11.0      9      6      0      0
# 4             0.0     0.000000  3.0   11.0      9      6      0      0
# 5             0.0     0.000000  3.0   11.0     10      6      0      0
# ...           ...          ...  ...    ...    ...    ...    ...    ...
# 996           0.0    15.871257  3.0   11.0     14     14     14     13
# 997           0.0    15.718463  3.0   11.0     14     14     14     13
# 998           0.0    15.487430  3.0   11.0     14     14     14     13
# 999           0.0    15.256397  3.0   11.0     14     14     14     12
# 1000          0.0    14.935654  3.0   11.0     14     14     14     12
#
# [1000 rows x 36 columns]

# %%
#creating summary df
df_call = pd.concat([df_c1, df_c2, df_c3], ignore_index=True)

cam_list = []
for i in range(1,4):
    cam_list = np.append(cam_list, np.full((1,15),[i]))

i=1
parab_list = []
while i <= 3:
    for j in range(1,16):
        parab_list = np.append(parab_list, j)
    i+=1

df_sum = pd.DataFrame({'cam': cam_list, 'parab': parab_list})


#getting the time it takes from the first instance to get to the percent
def timeto(df,  minslice):
    idxTime25 = (df.Nab25 >= minslice).idxmax()
    Timeto25 = df.Time.iloc[idxTime25] - df.Time.iloc[0]
    
    idxTime50 = (df.Nab50 >= minslice).idxmax()
    Timeto50 = df.Time.iloc[idxTime50] - df.Time.iloc[0]

    idxTime75 = (df.Nab75 >= minslice).idxmax()
    Timeto75 = df.Time.iloc[idxTime75] - df.Time.iloc[0]

    idxTime95 = (df.Nab95 >= minslice).idxmax()
    Timeto95 = df.Time.iloc[idxTime95] - df.Time.iloc[0]
    arr = [Timeto25, Timeto50, Timeto75, Timeto95]
    return np.array(arr)


arrofTimesto = []
for df in df_list: 
    arrofTimesto.append(timeto(df, 3))
    
arrofTimesto =  pd.DataFrame(np.array(arrofTimesto))
df_sum = pd.concat([df_sum, arrofTimesto], axis=1)
df_sum.rename(columns={0: 'Timeto25', 1: 'Timeto50', 2: 'Timeto75', 3: 'Timeto95'}, inplace=True)

# %%
df_sum
# Out:
#     cam  parab  Timeto25  Timeto50  Timeto75   Timeto95
# 0   1.0    1.0  0.033333  0.033333  0.066667   6.100000
# 1   1.0    2.0  0.033333  0.033333  0.633333   7.200000
# 2   1.0    3.0  0.066667  0.233333  2.033333   6.166667
# 3   1.0    4.0  0.066667  0.300000  2.266667  12.300000
# 4   1.0    5.0  0.200000  0.233333  2.033333   3.566667
# 5   1.0    6.0  0.033333  0.200000  0.766667   8.666667
# 6   1.0    7.0  0.100000  0.200000  0.466667   7.966667
# 7   1.0    8.0  0.033333  0.033333  1.200000   7.733333
# 8   1.0    9.0  0.033333  0.133333  1.433333   7.066667
# 9   1.0   10.0  0.033333  0.033333  0.166667   9.300000
# 10  1.0   11.0  0.066667  0.300000  0.966667  12.200000
# 11  1.0   12.0  0.033333  0.033333  0.466667   8.400000
# 12  1.0   13.0  0.033333  0.033333  0.333333   5.233333
# 13  1.0   14.0  0.033333  0.033333  0.733333   4.766667
# 14  1.0   15.0  0.033333  0.133333  1.666667  12.666667
# 15  2.0    1.0  0.033333  0.166667  0.333333   0.033333
# 16  2.0    2.0  0.033333  0.033333  0.100000   0.033333
# 17  2.0    3.0  0.033333  0.033333  0.233333  17.166667
# 18  2.0    4.0  0.033333  0.033333  0.433333   0.033333
# 19  2.0    5.0  0.033333  0.033333  0.233333   7.100000
# 20  2.0    6.0  0.033333  0.066667  0.266667   6.200000
# 21  2.0    7.0  0.033333  0.033333  0.133333   6.200000
# 22  2.0    8.0  0.033333  0.066667  0.233333   0.033333
# 23  2.0    9.0  0.033333  0.033333  0.233333   7.466667
# 24  2.0   10.0  0.033333  0.066667  0.300000   0.033333
# 25  2.0   11.0  0.033333  0.033333  0.500000  17.666667
# 26  2.0   12.0  0.033333  0.033333  0.400000   0.033333
# 27  2.0   13.0  0.033333  0.033333  0.066667   0.033333
# 28  2.0   14.0  0.033333  0.033333  0.100000  15.666667
# 29  2.0   15.0  0.033333  0.033333  0.066667   5.900000
# 30  3.0    1.0  0.033333  0.200000  0.300000  10.533333
# 31  3.0    2.0  0.033333  0.100000  0.366667  15.266667
# 32  3.0    3.0  0.033333  0.033333  1.100000  17.866667
# 33  3.0    4.0  0.033333  0.033333  0.133333   9.133333
# 34  3.0    5.0  0.033333  0.033333  0.033333   1.966667
# 35  3.0    6.0  0.033333  0.033333  0.233333  13.300000
# 36  3.0    7.0  0.033333  0.033333  0.066667  14.400000
# 37  3.0    8.0  0.033333  0.033333  0.100000   7.033333
# 38  3.0    9.0  0.033333  0.033333  0.533333   6.700000
# 39  3.0   10.0  0.033333  0.033333  0.300000  17.966667
# 40  3.0   11.0  0.033333  0.033333  0.266667   5.066667
# 41  3.0   12.0  0.033333  0.033333  0.066667   9.700000
# 42  3.0   13.0  0.033333  0.033333  0.266667  14.533333
# 43  3.0   14.0  0.033333  0.033333  0.100000   5.033333
# 44  3.0   15.0  0.033333  0.033333  0.966667   6.666667

# %%
import seaborn as sns
sns.boxplot(y='Timeto95', x='cam', data=df_sum, palette="colorblind")
# Out:
# <AxesSubplot:xlabel='cam', ylabel='Timeto95'>

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

model2 = ols('Timeto75 ~ C(cam)', data=df_sum).fit()
anova_table = sm.stats.anova_lm(model2, typ=2)
anova_table
# print(f"Overall model F({model2.df_model: },{model2.df_resid: }) = {model2.fvalue: }, p = {model2.f_pvalue: }")
# model2.summary()
# Out:
#             sum_sq    df          F    PR(>F)
# C(cam)    5.425778   2.0  12.754627  0.000047
# Residual  8.933333  42.0        NaN       NaN

# %%
# Create the ANOVA table
res2 = sm.stats.anova_lm(model2, typ=2)
res2

#Check the Normal distribution of residuals
res = model2.resid
fig = sm.qqplot(res, line='s')
plt.show()
# Out:
# /home/merge/env_merge/lib/python3.9/site-packages/statsmodels/graphics/gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
#post hoc tukey test
from bioinfokit.analys import stat

print('''#########################
    post hoc tests for time to X''')
res = stat()
res.tukey_hsd(df=df_sum, res_var='Timeto95', xfac_var='cam', anova_model='Timeto95 ~ C(cam)')
print("tukey summ, time to 95 \n\n", res.tukey_summary, "\n\n")

res.tukey_hsd(df=df_sum, res_var='Timeto75', xfac_var='cam', anova_model='Timeto75 ~ C(cam)')
print("tukey summ, time to 75 \n\n", res.tukey_summary, "\n\n")

res.tukey_hsd(df=df_sum, res_var='Timeto50', xfac_var='cam', anova_model='Timeto50 ~ C(cam)')
print("tukey summ, time to 50 \n\n", res.tukey_summary, "\n\n")

res.tukey_hsd(df=df_sum, res_var='Timeto25', xfac_var='cam', anova_model='Timeto25 ~ C(cam)')
print("tukey summ, time to 25 \n\n", res.tukey_summary)
# Out:
# #########################
#     post hoc tests for time to X
# tukey summ, time to 95
#
#     group1  group2      Diff     Lower     Upper   q-value   p-value
# 0     1.0     2.0  2.382222 -2.070630  6.835075  1.838056  0.404841
# 1     1.0     3.0  2.388889 -2.063963  6.841741  1.843200  0.402818
# 2     2.0     3.0  4.771111  0.318259  9.223963  3.681257  0.033344
#
#
# tukey summ, time to 75
#
#     group1  group2      Diff     Lower     Upper   q-value   p-value
# 0     1.0     2.0  0.773333  0.364213  1.182454  6.494268  0.001000
# 1     1.0     3.0  0.693333  0.284213  1.102454  5.822448  0.001000
# 2     2.0     3.0  0.080000 -0.329121  0.489121  0.671821  0.875339
#
#
# tukey summ, time to 50
#
#     group1  group2          Diff     Lower     Upper       q-value   p-value
# 0     1.0     2.0  8.222222e-02  0.020939  0.143505  4.609592e+00  0.006144
# 1     1.0     3.0  8.222222e-02  0.020939  0.143505  4.609592e+00  0.006144
# 2     2.0     3.0  5.551115e-17 -0.061283  0.061283  3.112100e-15  0.900000
#
#
# tukey summ, time to 25
#
#     group1  group2      Diff     Lower     Upper  q-value   p-value
# 0     1.0     2.0  0.022222 -0.000743  0.045187  3.32455  0.059705
# 1     1.0     3.0  0.022222 -0.000743  0.045187  3.32455  0.059705
# 2     2.0     3.0  0.000000 -0.022965  0.022965  0.00000  0.900000

# %%
df_sum
# Out:
#     cam  parab  Timeto25  Timeto50  Timeto75   Timeto95
# 0   1.0    1.0  0.033333  0.033333  0.066667   6.100000
# 1   1.0    2.0  0.033333  0.033333  0.633333   7.200000
# 2   1.0    3.0  0.066667  0.233333  2.033333   6.166667
# 3   1.0    4.0  0.066667  0.300000  2.266667  12.300000
# 4   1.0    5.0  0.200000  0.233333  2.033333   3.566667
# 5   1.0    6.0  0.033333  0.200000  0.766667   8.666667
# 6   1.0    7.0  0.100000  0.200000  0.466667   7.966667
# 7   1.0    8.0  0.033333  0.033333  1.200000   7.733333
# 8   1.0    9.0  0.033333  0.133333  1.433333   7.066667
# 9   1.0   10.0  0.033333  0.033333  0.166667   9.300000
# 10  1.0   11.0  0.066667  0.300000  0.966667  12.200000
# 11  1.0   12.0  0.033333  0.033333  0.466667   8.400000
# 12  1.0   13.0  0.033333  0.033333  0.333333   5.233333
# 13  1.0   14.0  0.033333  0.033333  0.733333   4.766667
# 14  1.0   15.0  0.033333  0.133333  1.666667  12.666667
# 15  2.0    1.0  0.033333  0.166667  0.333333   0.033333
# 16  2.0    2.0  0.033333  0.033333  0.100000   0.033333
# 17  2.0    3.0  0.033333  0.033333  0.233333  17.166667
# 18  2.0    4.0  0.033333  0.033333  0.433333   0.033333
# 19  2.0    5.0  0.033333  0.033333  0.233333   7.100000
# 20  2.0    6.0  0.033333  0.066667  0.266667   6.200000
# 21  2.0    7.0  0.033333  0.033333  0.133333   6.200000
# 22  2.0    8.0  0.033333  0.066667  0.233333   0.033333
# 23  2.0    9.0  0.033333  0.033333  0.233333   7.466667
# 24  2.0   10.0  0.033333  0.066667  0.300000   0.033333
# 25  2.0   11.0  0.033333  0.033333  0.500000  17.666667
# 26  2.0   12.0  0.033333  0.033333  0.400000   0.033333
# 27  2.0   13.0  0.033333  0.033333  0.066667   0.033333
# 28  2.0   14.0  0.033333  0.033333  0.100000  15.666667
# 29  2.0   15.0  0.033333  0.033333  0.066667   5.900000
# 30  3.0    1.0  0.033333  0.200000  0.300000  10.533333
# 31  3.0    2.0  0.033333  0.100000  0.366667  15.266667
# 32  3.0    3.0  0.033333  0.033333  1.100000  17.866667
# 33  3.0    4.0  0.033333  0.033333  0.133333   9.133333
# 34  3.0    5.0  0.033333  0.033333  0.033333   1.966667
# 35  3.0    6.0  0.033333  0.033333  0.233333  13.300000
# 36  3.0    7.0  0.033333  0.033333  0.066667  14.400000
# 37  3.0    8.0  0.033333  0.033333  0.100000   7.033333
# 38  3.0    9.0  0.033333  0.033333  0.533333   6.700000
# 39  3.0   10.0  0.033333  0.033333  0.300000  17.966667
# 40  3.0   11.0  0.033333  0.033333  0.266667   5.066667
# 41  3.0   12.0  0.033333  0.033333  0.066667   9.700000
# 42  3.0   13.0  0.033333  0.033333  0.266667  14.533333
# 43  3.0   14.0  0.033333  0.033333  0.100000   5.033333
# 44  3.0   15.0  0.033333  0.033333  0.966667   6.666667

# %%
print('''#########################
    post hoc tests for frac X''')
res = stat()
res.tukey_hsd(df=df_sum, res_var='frac95', xfac_var='cam', anova_model='frac95 ~ C(cam)')
print("tukey summ, frac75 \n\n", res.tukey_summary, "\n\n")

res.tukey_hsd(df=df_sum, res_var='frac75', xfac_var='cam', anova_model='frac75 ~ C(cam)')
print("tukey summ, frac75 \n\n", res.tukey_summary, "\n\n")

res.tukey_hsd(df=df_sum, res_var='frac50', xfac_var='cam', anova_model='frac50 ~ C(cam)')
print("tukey summ, frac50 \n\n", res.tukey_summary, "\n\n")

res.tukey_hsd(df=df_sum, res_var='frac25', xfac_var='cam', anova_model='frac25 ~ C(cam)')
print("tukey summ, frac25 \n\n", res.tukey_summary)
# Out:
# #########################
#     post hoc tests for frac X
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/env_merge/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/env_merge/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/env_merge/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'frac95'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2909/117102515.py in <module>
#       2     post hoc tests for frac X''')
#       3 res = stat()
# ----> 4 res.tukey_hsd(df=df_sum, res_var='frac95', xfac_var='cam', anova_model='frac95 ~ C(cam)')
#       5 print("tukey summ, frac75 \n\n", res.tukey_summary, "\n\n")
#       6
#
# ~/env_merge/lib/python3.9/site-packages/bioinfokit/analys.py in tukey_hsd(self, df, res_var, xfac_var, anova_model, phalpha, ss_typ)
#     837         # share_let = dict()
#     838
# --> 839         mult_group, mult_group_count, sample_size_r = analys_general.get_list_from_df(df, xfac_var, res_var, 'get_dict')
#     840
#     841         # self.anova_stat(df, res_var, anova_xfac_var)
#
# ~/env_merge/lib/python3.9/site-packages/bioinfokit/analys.py in get_list_from_df(df, xfac_var, res_var, funct)
#     400                     df_counts += 1
#     401                 elif funct == 'get_dict':
# --> 402                     mult_group[ele] = df[df[xfac_var] == ele].mean().loc[res_var]
#     403                     mult_group_count[ele] = df[df[xfac_var] == ele].shape[0]
#     404         elif isinstance(xfac_var, list) and len(xfac_var) > 3:
#
# ~/env_merge/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/env_merge/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/env_merge/lib/python3.9/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~/env_merge/lib/python3.9/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3774                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3775         else:
# -> 3776             loc = index.get_loc(key)
#    3777
#    3778             if isinstance(loc, np.ndarray):
#
# ~/env_merge/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'frac95'

# %%
#Approach 2 - Check the interaction of groups
formula = 'Timeto50 ~ C(cam)'
model = ols(formula, df_sum).fit()
model.summary()

# %%
aov_table = sm.stats.anova_lm(model, typ=2)
print(aov_table.round(4))

# %%
from scipy import stats

F, p = stats.f_oneway(df_sum.loc[df_sum['cam']==1,["Timeto50"]], df_sum.loc[df_sum['cam']==2,["Timeto50"]],df_sum.loc[df_sum['cam']==3,["Timeto50"]])
p

# %%
###amount of time spent above

def timespent(df,  minslice):
    timediffframes = df.Time.iloc[1] - df.Time.iloc[0]
    tottime = df.Time.iloc[-1] - df.Time.iloc[0]

    frames25 = len(df.Nab25 >= minslice)
    timespent = frames25 * timediffframes
    frac25 = timespent / tottime
    
    frames50 = len(df.Nab50 >= minslice)
    timespent = frames50 * timediffframes
    frac50 = timespent / tottime
    
    frames75 = len(df.Nab75 >= minslice)
    timespent = frames75 * timediffframes
    frac75 = timespent / tottime
    
    frames95 = len(df.Nab95 >= minslice)
    timespent = frames95 * timediffframes
    frac95 = timespent / tottime

    arr = [frac25, frac50, frac75, frac95]
    return np.array(arr)


arrofTimespent = []
for df in df_list: 
    arrofTimespent.append(timespent(df, 3))
    
arrofTimesto =  pd.DataFrame(np.array(arrofTimespent))
df_sum = pd.concat([df_sum, arrofTimespent], axis=1)
df_sum.rename(columns={0: 'frac25', 1: 'frac50', 2: 'frac75', 3: 'frac95'}, inplace=True)

# df = df_c2p11
# numofframe = len(df.Nab25 >= minslice)
df_sum

# %%
df_c1["Max"] = df_c1.filter(regex=("Slice.*"),axis=1).max(axis=1)
df_c2["Max"] = df_c2.filter(regex=("Slice.*"),axis=1).max(axis=1)
df_c3["Max"] = df_c3.filter(regex=("Slice.*"),axis=1).max(axis=1)

df_c1["Median"] = df_c1.filter(regex=("Slice.*"),axis=1).median(axis=1)
df_c2["Median"] = df_c2.filter(regex=("Slice.*"),axis=1).median(axis=1)
df_c3["Median"] = df_c3.filter(regex=("Slice.*"),axis=1).median(axis=1)

# %%
window=50
df_c1_sorted_time = df_c1.sort_values(by=["Time"])
df_c1_sorted_time["Roll_Max_W10"] = df_c1_sorted_time.loc[:,"Max"].rolling(window=10).mean()
df_c1_sorted_time["Roll_Max_W50"] = df_c1_sorted_time.loc[:,"Max"].rolling(window=50).mean()
df_c1_sorted_time["Roll_Max_W100"] = df_c1_sorted_time.loc[:,"Max"].rolling(window=100).mean()
df_c1_sorted_time["Roll_Max_Wcust"] = df_c1_sorted_time.loc[:,"Max"].rolling(window=window).mean()


df_c2_sorted_time = df_c2.sort_values(by=["Time"])
df_c2_sorted_time["Roll_Max_W10"] = df_c2_sorted_time.loc[:,"Max"].rolling(window=10).mean()
df_c2_sorted_time["Roll_Max_W50"] = df_c2_sorted_time.loc[:,"Max"].rolling(window=50).mean()
df_c2_sorted_time["Roll_Max_W100"] = df_c2_sorted_time.loc[:,"Max"].rolling(window=100).mean()
df_c2_sorted_time["Roll_Max_Wcust"] = df_c2_sorted_time.loc[:,"Max"].rolling(window=window).mean()


df_c3_sorted_time = df_c3.sort_values(by=["Time"])
df_c3_sorted_time["Roll_Max_W10"] = df_c3_sorted_time.loc[:,"Max"].rolling(window=10).mean()
df_c3_sorted_time["Roll_Max_W50"] = df_c3_sorted_time.loc[:,"Max"].rolling(window=50).mean()
df_c3_sorted_time["Roll_Max_W100"] = df_c3_sorted_time.loc[:,"Max"].rolling(window=100).mean()
df_c3_sorted_time["Roll_Max_Wcust"] = df_c3_sorted_time.loc[:,"Max"].rolling(window=window).mean()

# %%
# plt.scatter(df_c1.loc[:,["Time"]], df_c1.loc[:,["Max"]], label="Cam 1 Max", color='black', alpha=0.5)
# plt.scatter(df_c2.loc[:,["Time"]], df_c2.loc[:,["Max"]], label="Cam 2 Max", color='blue', alpha=0.5)
# plt.scatter(df_c3.loc[:,["Time"]], df_c3.loc[:,["Max"]], label="Cam 3 Max", color='red', alpha=0.5)
# plt.legend()

plt.figure(figsize=(10,6))
plt.plot(df_c1_sorted_time.loc[:,["Time"]], df_c1_sorted_time.loc[:,["Roll_Max_W10"]], 
         label="Cam 1 Max", color='black', alpha=0.4)
plt.plot(df_c1_sorted_time.loc[:,["Time"]], df_c1_sorted_time.loc[:,["Roll_Max_W100"]], 
         label="Cam 1 Max", color='black', alpha=0.8)


plt.plot(df_c2_sorted_time.loc[:,["Time"]], df_c2_sorted_time.loc[:,["Roll_Max_W10"]], 
         label="Cam 2 Max", color='blue', alpha=0.4)
plt.plot(df_c2_sorted_time.loc[:,["Time"]], df_c2_sorted_time.loc[:,["Roll_Max_W100"]], 
         label="Cam 2 Max", color='blue', alpha=0.8)

plt.plot(df_c3_sorted_time.loc[:,["Time"]], df_c3_sorted_time.loc[:,["Roll_Max_W10"]], 
         label="Cam 3 Max", color='red', alpha=0.5)
plt.plot(df_c3_sorted_time.loc[:,["Time"]], df_c3_sorted_time.loc[:,["Roll_Max_W100"]], 
         label="Cam 3 Max", color='red', alpha=0.8)
plt.legend()

# %%
window=200
df_c1_sorted_time = df_c1.sort_values(by=["Time"])
df_c1_sorted_time["Roll_Med_W10"] = df_c1_sorted_time.loc[:,"Median"].rolling(window=10).mean()
df_c1_sorted_time["Roll_Med_W50"] = df_c1_sorted_time.loc[:,"Median"].rolling(window=50).mean()
df_c1_sorted_time["Roll_Med_W100"] = df_c1_sorted_time.loc[:,"Median"].rolling(window=100).mean()
df_c1_sorted_time["Roll_Med_Wcust"] = df_c1_sorted_time.loc[:,"Median"].rolling(window=window).mean()

df_c2_sorted_time = df_c2.sort_values(by=["Time"])
df_c2_sorted_time["Roll_Med_W10"] = df_c2_sorted_time.loc[:,"Median"].rolling(window=10).mean()
df_c2_sorted_time["Roll_Med_W50"] = df_c2_sorted_time.loc[:,"Median"].rolling(window=50).mean()
df_c2_sorted_time["Roll_Med_W100"] = df_c2_sorted_time.loc[:,"Median"].rolling(window=100).mean()
df_c2_sorted_time["Roll_Med_Wcust"] = df_c2_sorted_time.loc[:,"Median"].rolling(window=window).mean()

df_c3_sorted_time = df_c3.sort_values(by=["Time"])
df_c3_sorted_time["Roll_Med_W10"] = df_c3_sorted_time.loc[:,"Median"].rolling(window=10).mean()
df_c3_sorted_time["Roll_Med_W50"] = df_c3_sorted_time.loc[:,"Median"].rolling(window=50).mean()
df_c3_sorted_time["Roll_Med_W100"] = df_c3_sorted_time.loc[:,"Median"].rolling(window=100).mean()
df_c3_sorted_time["Roll_Med_Wcust"] = df_c3_sorted_time.loc[:,"Median"].rolling(window=window).mean()

# %%
plt.figure(figsize=(10,8))
plt.plot(df_c1_sorted_time.loc[:,["Time"]], 
         df_c1_sorted_time.loc[:,["Roll_Med_W10"]], label="Cam 1 Rolling Med 10", color='black', alpha=0.4)
plt.plot(df_c1_sorted_time.loc[:,["Time"]], 
         df_c1_sorted_time.loc[:,["Roll_Med_W100"]], label="Cam 1 Rolling Med 100", color='black')

plt.plot(df_c2_sorted_time.loc[:,["Time"]], 
         df_c2_sorted_time.loc[:,["Roll_Med_W10"]], label="Cam 2 Med", color='blue', alpha=0.4)
plt.plot(df_c2_sorted_time.loc[:,["Time"]], 
         df_c2_sorted_time.loc[:,["Roll_Med_W100"]], label="Cam 2 Med", color='blue')

plt.plot(df_c3_sorted_time.loc[:,["Time"]], 
         df_c3_sorted_time.loc[:,["Roll_Med_W10"]], label="Cam 3 Med", color='red', alpha=0.4)
plt.plot(df_c3_sorted_time.loc[:,["Time"]], 
         df_c3_sorted_time.loc[:,["Roll_Med_W100"]], label="Cam 3 Med", color='red')
plt.legend()

# %%
## seeing how """"""off"""""" parabs are from one another

# fig, ax = plt.subplots()  # Here we create the axes that all data will plot onto
plt.figure(figsize=(10,8))
for i in range(1,15):
    plt.plot(df_c1.loc[df_c1["parab"]==i,"Time"], df_c1.loc[df_c1["parab"]==i,["Max"]], 
             label="Cam 1 Med, parab %i" %i, alpha=0.8, color='black')
    plt.plot(df_c2.loc[df_c2["parab"]==i,"Time"], df_c2.loc[df_c2["parab"]==i,["Max"]], 
             label="Cam 2 Med, parab %i" %i, alpha=0.8, color='red')
    plt.plot(df_c3.loc[df_c3["parab"]==i,"Time"], df_c3.loc[df_c3["parab"]==i,["Max"]], 
             label="Cam 3 Med, parab %i" %i, alpha=0.8, color='blue')
#     plt.plot(df_c1.loc[df_c1["parab"]==2.0,"Time"], df_c1.loc[df_c1["parab"]==2,["Max"]], label="Cam 1 Med, parab 2", color='blue', alpha=0.8)
    plt.legend()
#     plt.xlim(0,3)

# %%
ax = plt.gca()
plt.rcdefaults()
plt.rcParams["font.family"] = "serif"
plt.rcParams['font.size'] = 10
ax.xaxis.set_tick_params(which='major', direction='in', bottom='on')
ax.yaxis.set_tick_params(which='major', direction='in', left='on')
plt.plot(df_c3.loc[df_c3["parab"]==2,"Time"], df_c3.loc[df_c3["parab"]==2,["Max"]], 
             label="Cam 3 Med, parab 3", alpha=0.8, color='maroon')
plt.xlabel('Time (s)', labelpad=10)
plt.ylabel('Maximum Fluid Height (cm)', labelpad=10)
plt.savefig('fc72timeseries'+'.png', dpi=300, transparent=False, bbox_inches='tight')
plt.show()

# %%
i=14
plt.plot(df_c1.loc[df_c1["parab"]==i,"Time"], df_c1.loc[df_c1["parab"]==i,["Max"]], label="Cam 1 Med, parab %i" %i, alpha=0.8)

# %%
# Out:
#         Frame       Time  Slice1_Min  Slice1_Max  Slice2_Min  Slice2_Max  \
# 0         0.0   0.000000         0.0    0.000000         0.0    0.000000
# 1         1.0   0.033333         0.0    0.000000         0.0    0.000000
# 2         2.0   0.066667         0.0    0.000000         0.0    0.000000
# 3         3.0   0.100000         0.0    0.000000         0.0    0.000000
# 4         4.0   0.133333         0.0    0.000000         0.0    0.000000
# ...       ...        ...         ...         ...         ...         ...
# 35325   996.0  33.200000         0.0   11.957617         0.0    8.085350
# 35326   997.0  33.233333         0.0   11.786799         0.0    8.082072
# 35327   998.0  33.266667         0.0   11.665548         0.0    8.063229
# 35328   999.0  33.300000         0.0   11.544296         0.0    8.044386
# 35329  1000.0  33.333333         0.0   11.515622         0.0    8.063229
#
#        Slice3_Min  Slice3_Max  Slice4_Min  Slice4_Max  Slice5_Min  Slice5_Max  \
# 0             0.0     0.00000         0.0    3.644920         0.0    3.873496
# 1             0.0     0.00000         0.0    4.969676         0.0    5.290829
# 2             0.0     0.00000         0.0    6.294431         0.0    6.708161
# 3             0.0     0.00000         0.0    7.344322         0.0    7.958773
# 4             0.0     0.00000         0.0    8.394213         0.0    9.209384
# ...           ...         ...         ...         ...         ...         ...
# 35325         0.0    12.16612         0.0   12.166120         0.0    8.270094
# 35326         0.0    12.16612         0.0   12.166120         0.0    7.810076
# 35327         0.0    12.16612         0.0   12.166120         0.0    7.509405
# 35328         0.0    12.16612         0.0   12.166120         0.0    7.208733
# 35329         0.0    12.16612         0.0   12.166120         0.0    6.844979
#
#        Slice6_Min  Slice6_Max  Slice7_Min  Slice7_Max  Slice8_Min  Slice8_Max  \
# 0             0.0    0.000000         0.0   13.977520         0.0   13.979159
# 1             0.0    0.000000         0.0   14.721415         0.0   14.724692
# 2             0.0    0.000000         0.0   15.465310         0.0   15.470225
# 3             0.0    0.000000         0.0   15.764342         0.0   15.771716
# 4             0.0    0.000000         0.0   16.063375         0.0   16.073206
# ...           ...         ...         ...         ...         ...         ...
# 35325         0.0   11.735186         0.0   11.693045         0.0   11.524634
# 35326         0.0   12.063712         0.0   11.702620         0.0   11.524634
# 35327         0.0   12.084808         0.0   11.717264         0.0   11.524634
# 35328         0.0   12.105904         0.0   11.731909         0.0   11.524634
# 35329         0.0   12.159361         0.0   11.734162         0.0   11.524634
#
#        Slice9_Min  Slice9_Max  Slice10_Min  Slice10_Max  Slice11_Min  \
# 0             0.0    8.740763          0.0     8.871846          0.0
# 1             0.0    9.205698          0.0     9.382659          0.0
# 2             0.0    9.670632          0.0     9.893473          0.0
# 3             0.0    9.205698          0.0    10.118771          0.0
# 4             0.0    8.740763          0.0    10.344070          0.0
# ...           ...         ...          ...          ...          ...
# 35325         0.0    5.083554          0.0    12.166120          0.0
# 35326         0.0    5.063072          0.0    12.166120          0.0
# 35327         0.0    5.153806          0.0    12.166120          0.0
# 35328         0.0    5.244540          0.0    12.166120          0.0
# 35329         0.0    5.247612          0.0    12.166120          0.0
#
#        Slice11_Max  Slice12_Min  Slice12_Max  Slice13_Min  Slice13_Max  \
# 0         9.874629          0.0     9.885280          0.0     6.615584
# 1        11.616392          0.0    11.627862          0.0     6.615584
# 2        13.358154          0.0    13.370443          0.0     6.615584
# 3        12.877654          0.0    13.359793          0.0     5.350840
# 4        12.397154          0.0    13.349142          0.0     4.086096
# ...            ...          ...          ...          ...          ...
# 35325    12.166120          0.0    11.238300          0.0    11.891256
# 35326    12.166120          0.0    11.224782          0.0    11.924436
# 35327    12.166120          0.0    11.195698          0.0    12.061254
# 35328    12.166120          0.0    11.166614          0.0    12.198072
# 35329    12.166120          0.0    11.195698          0.0    12.422756
#
#        Slice14_Min  Slice14_Max  cam parab        Max    Median
# 0              0.0     2.059638  1.0   1.0  13.979159  0.000000
# 1              0.0     2.560210  1.0   1.0  14.724692  0.000000
# 2              0.0     3.060783  1.0   1.0  15.470225  0.000000
# 3              0.0     2.964929  1.0   1.0  15.771716  0.000000
# 4              0.0     2.869074  1.0   1.0  16.073206  0.000000
# ...            ...          ...  ...   ...        ...       ...
# 35325          0.0    12.412310  3.0  15.0  12.412310  2.541777
# 35326          0.0    12.391419  3.0  15.0  12.391419  2.531536
# 35327          0.0    12.310721  3.0  15.0  12.310721  2.576903
# 35328          0.0    12.391419  3.0  15.0  12.391419  2.622270
# 35329          0.0    12.857787  3.0  15.0  12.857787  2.623806
#
# [35330 rows x 34 columns]

# %%
##startng anova
df_call = pd.concat([df_c1, df_c2, df_c3], ignore_index=True)
import seaborn as sns
ax = sns.boxplot(x='cam', y='Max', data=df_call)

# %%
from scipy import stats

F, p = stats.f_oneway(df_call.loc[df_call['cam']==1,["Max"]], df_call.loc[df_call['cam']==2,["Max"]],df_call.loc[df_call['cam']==3,["Max"]])
F
# Out:
# array([771.29802639])

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

model=ols('Max ~ C(cam)', data=df_call).fit()
print(sm.stats.anova_lm(model, typ=2))
# Out:
#                  sum_sq       df           F  PR(>F)
# C(cam)     10776.588027      2.0  771.298026     0.0
# Residual  246794.696865  35327.0         NaN     NaN

# %%
import scipy.stats as ss
for name_group in df_call.groupby('cam'):
    samples = [Max[1] for Max in name_group[1].groupby('Max')['Max']]
    f_val, p_val = ss.f_oneway(*samples)
    print('Cam: {}, F value: {:.3f}, p value: {:.10f}'.format(name_group[0], f_val, p_val))
# Out:
# Cam: 1.0, F value: inf, p value: 0.0000000000
# Cam: 2.0, F value: inf, p value: 0.0000000000
# Cam: 3.0, F value: inf, p value: 0.0000000000
