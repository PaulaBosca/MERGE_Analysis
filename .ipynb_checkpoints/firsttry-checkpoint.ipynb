# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
# load cam 1
path_fc = r'/home/merge/merge/fc72/edited_headers'

df_c1p1 = pd.read_excel(path_fc+'/cam1parab1'+'_filtered.xlsx', index_col=None, header=0)
df_c1p2 = pd.read_excel(path_fc+'/cam1parab2'+'_filtered.xlsx', index_col=None, header=0)
df_c1p3 = pd.read_excel(path_fc+'/cam1parab3'+'_filtered.xlsx', index_col=None, header=0)
df_c1p4 = pd.read_excel(path_fc+'/cam1parab4'+'_filtered.xlsx', index_col=None, header=0)
df_c1p5 = pd.read_excel(path_fc+'/cam1parab5'+'_filtered.xlsx', index_col=None, header=0)
df_c1p6 = pd.read_excel(path_fc+'/cam1parab6'+'_filtered.xlsx', index_col=None, header=0)
df_c1p7 = pd.read_excel(path_fc+'/cam1parab7'+'_filtered.xlsx', index_col=None, header=0)
df_c1p8 = pd.read_excel(path_fc+'/cam1parab8'+'_filtered.xlsx', index_col=None, header=0)
df_c1p9 = pd.read_excel(path_fc+'/cam1parab9'+'_filtered.xlsx', index_col=None, header=0)
df_c1p10 = pd.read_excel(path_fc+'/cam1parab10'+'_filtered.xlsx', index_col=None, header=0)
df_c1p11 = pd.read_excel(path_fc+'/cam1parab11'+'_filtered.xlsx', index_col=None, header=0)
df_c1p12 = pd.read_excel(path_fc+'/cam1parab12'+'_filtered.xlsx', index_col=None, header=0)
df_c1p13 = pd.read_excel(path_fc+'/cam1parab13'+'_filtered.xlsx', index_col=None, header=0)
df_c1p14 = pd.read_excel(path_fc+'/cam1parab14'+'_filtered.xlsx', index_col=None, header=0)
df_c1p15 = pd.read_excel(path_fc+'/cam1parab15'+'_filtered.xlsx', index_col=None, header=0)

df_c1 = pd.concat([df_c1p1, df_c1p2, df_c1p3, df_c1p4, df_c1p5, df_c1p6, df_c1p7, 
                   df_c1p8, df_c1p9, df_c1p10, df_c1p11, df_c1p12, df_c1p13, df_c1p14, df_c1p15],ignore_index=True)

# %%
#load cam2
path_fc = r'/home/merge/merge/fc72/edited_headers'

df_c2p1 = pd.read_excel(path_fc+'/cam2parab1'+'_filtered.xlsx', index_col=None, header=0)
df_c2p2 = pd.read_excel(path_fc+'/cam2parab2'+'_filtered.xlsx', index_col=None, header=0)
df_c2p3 = pd.read_excel(path_fc+'/cam2parab3'+'_filtered.xlsx', index_col=None, header=0)
df_c2p4 = pd.read_excel(path_fc+'/cam2parab4'+'_filtered.xlsx', index_col=None, header=0)
df_c2p5 = pd.read_excel(path_fc+'/cam2parab5'+'_filtered.xlsx', index_col=None, header=0)
df_c2p6 = pd.read_excel(path_fc+'/cam2parab6'+'_filtered.xlsx', index_col=None, header=0)
df_c2p7 = pd.read_excel(path_fc+'/cam2parab7'+'_filtered.xlsx', index_col=None, header=0)
df_c2p8 = pd.read_excel(path_fc+'/cam2parab8'+'_filtered.xlsx', index_col=None, header=0)
df_c2p9 = pd.read_excel(path_fc+'/cam2parab9'+'_filtered.xlsx', index_col=None, header=0)
df_c2p10 = pd.read_excel(path_fc+'/cam2parab10'+'_filtered.xlsx', index_col=None, header=0)
df_c2p11 = pd.read_excel(path_fc+'/cam2parab11'+'_filtered.xlsx', index_col=None, header=0)
df_c2p12 = pd.read_excel(path_fc+'/cam2parab12'+'_filtered.xlsx', index_col=None, header=0)
df_c2p13 = pd.read_excel(path_fc+'/cam2parab13'+'_filtered.xlsx', index_col=None, header=0)
df_c2p14 = pd.read_excel(path_fc+'/cam2parab14'+'_filtered.xlsx', index_col=None, header=0)
df_c2p15 = pd.read_excel(path_fc+'/cam2parab15'+'_filtered.xlsx', index_col=None, header=0)


df_c2 = pd.concat([df_c2p1, df_c2p2, df_c2p3, df_c2p4, df_c2p5, df_c2p6, df_c2p7, 
                   df_c2p8, df_c2p9, df_c2p10, df_c2p11, df_c2p12, df_c2p13, df_c2p14, df_c2p15],ignore_index=True)

# %%
#load cam3
path_fc = r'/home/merge/merge/fc72/edited_headers'

df_c3p1 = pd.read_excel(path_fc+'/cam3parab1'+'_filtered.xlsx', index_col=None, header=0)
df_c3p2 = pd.read_excel(path_fc+'/cam3parab2'+'_filtered.xlsx', index_col=None, header=0)
df_c3p3 = pd.read_excel(path_fc+'/cam3parab3'+'_filtered.xlsx', index_col=None, header=0)
df_c3p4 = pd.read_excel(path_fc+'/cam3parab4'+'_filtered.xlsx', index_col=None, header=0)
df_c3p5 = pd.read_excel(path_fc+'/cam3parab5'+'_filtered.xlsx', index_col=None, header=0)
df_c3p6 = pd.read_excel(path_fc+'/cam3parab6'+'_filtered.xlsx', index_col=None, header=0)
df_c3p7 = pd.read_excel(path_fc+'/cam3parab7'+'_filtered.xlsx', index_col=None, header=0)
df_c3p8 = pd.read_excel(path_fc+'/cam3parab8'+'_filtered.xlsx', index_col=None, header=0)
df_c3p9 = pd.read_excel(path_fc+'/cam3parab9'+'_filtered.xlsx', index_col=None, header=0)
df_c3p10 = pd.read_excel(path_fc+'/cam3parab10'+'_filtered.xlsx', index_col=None, header=0)
df_c3p11 = pd.read_excel(path_fc+'/cam3parab11'+'_filtered.xlsx', index_col=None, header=0)
df_c3p12 = pd.read_excel(path_fc+'/cam3parab12'+'_filtered.xlsx', index_col=None, header=0)
df_c3p13 = pd.read_excel(path_fc+'/cam3parab13'+'_filtered.xlsx', index_col=None, header=0)
df_c3p14 = pd.read_excel(path_fc+'/cam3parab14'+'_filtered.xlsx', index_col=None, header=0)
df_c3p15 = pd.read_excel(path_fc+'/cam3parab15'+'_filtered.xlsx', index_col=None, header=0)


df_c3 = pd.concat([df_c3p1, df_c3p2, df_c3p3, df_c3p4, df_c3p5, df_c3p6, df_c3p7, 
                   df_c3p8, df_c3p9, df_c3p10, df_c3p11, df_c3p12, df_c3p13, df_c3p14, df_c3p15], ignore_index=True)

# %%
df_c1["Max"] = df_c1.filter(regex=("Slice.*_Max"),axis=1).max(axis=1)
df_c2["Max"] = df_c2.filter(regex=("Slice.*_Max"),axis=1).max(axis=1)
df_c3["Max"] = df_c3.filter(regex=("Slice.*_Max"),axis=1).max(axis=1)

# %%
plt.clf()
plt.figure(dpi=200)
# df_c1.iloc[0:5000].plot(x="Time", y="Max", use_index=False, label="Cam1", kind='line')
plt.plot(df_c1["Time"], df_c1["Max"], '.', label='Cam1', alpha=0.5)
# plt.plot(df_c2["Time"], df_c2["Max"], '.', label='Cam2', alpha=0.5)
# plt.plot(df_c3["Time"], df_c3["Max"], '.', label='Cam3', alpha=0.5)
plt.xlabel("Time")
plt.ylabel("Max height")
plt.legend()

# %%
df_c1_0s = df_c1[df_c1['Time'] == 0].index.tolist() #cam1 locations of time ==0 in dF_c1  (cam1 df)

# fig, ax = plt.subplots()  # Here we create the axes that all data will plot onto
fig,ax = plt.subplots(figsize=(12,10))
for i in range(0,2):
# for i in range(0,len(df_c1_0s)-1):
    df_c1.iloc[df_c1_0s[i]:df_c1_0s[i+1]].plot(x="Time", y="Max", 
                                               use_index=False, label="parab"+str(i+1), ax=ax, marker='.')

# %%
df_c2_0s = df_c2[df_c2['Time'] == 0].index.tolist() #cam1 locations of time ==0 in dF_c1  (cam1 df)

# fig, ax = plt.subplots()  # Here we create the axes that all data will plot onto
fig,ax = plt.subplots(figsize=(12,10))
for i in range(0,len(df_c2_0s)-1):
    df_c2.iloc[df_c2_0s[i]:df_c2_0s[i+1]].plot(x="Time", y="Max", 
                                               use_index=False, label="parab"+str(i+1), ax=ax, marker='.')

# %%
df_c3_0s = df_c3[df_c3['Time'] == 0].index.tolist() #cam1 locations of time ==0 in dF_c1  (cam1 df)

# fig, ax = plt.subplots()  # Here we create the axes that all data will plot onto
fig,ax = plt.subplots(figsize=(12,10))
for i in range(0,len(df_c3_0s)-1):
    df_c3.iloc[df_c3_0s[i]:df_c3_0s[i+1]].plot(x="Time", y="Max", 
                                               use_index=False, label="parab"+str(i+1), ax=ax, marker='.')

# %%
# fig, ax = plt.subplots()  # Here we create the axes that all data will plot onto
fig,ax = plt.subplots(figsize=(16,14))
for i in range(0,len(df_c3_0s)-1):
    df_c3.iloc[df_c3_0s[i]:df_c3_0s[i+1]].plot(x="Time", y="Max", 
                                               use_index=False, label="cam 3 parab"+str(i+1), ax=ax, marker='.',color='black')
for i in range(0,len(df_c2_0s)-1):
    df_c2.iloc[df_c2_0s[i]:df_c2_0s[i+1]].plot(x="Time", y="Max", 
                                               use_index=False, label="cam 2 parab"+str(i+1), ax=ax, marker='.',color='blue')
for i in range(0,len(df_c1_0s)-1):
    df_c1.iloc[df_c1_0s[i]:df_c1_0s[i+1]].plot(x="Time", y="Max", 
                                               use_index=False, label="cam 1parab"+str(i+1), ax=ax, marker='.',color='red')

# %%
df_call = pd.concat([df_c1, df_c2, df_c3], ignore_index=True)

# %%
pd.reset_option("display.max_columns")

# %%
parab1 = df_call[df_call["parab"].isin([1])]
parab2 = df_call[df_call["parab"].isin([2])]
parab3 = df_call[df_call["parab"].isin([3])]
parab4 = df_call[df_call["parab"].isin([4])]
parab5 = df_call[df_call["parab"].isin([5])]
parab6 = df_call[df_call["parab"].isin([6])]
parab7 = df_call[df_call["parab"].isin([7])]
parab8 = df_call[df_call["parab"].isin([8])]
parab9 = df_call[df_call["parab"].isin([9])]
parab10 = df_call[df_call["parab"].isin([10])]
parab11 = df_call[df_call["parab"].isin([11])]
parab12 = df_call[df_call["parab"].isin([12])]
parab13 = df_call[df_call["parab"].isin([13])]
parab14 = df_call[df_call["parab"].isin([14])]
parab15 = df_call[df_call["parab"].isin([15])]

# %%
parab1["maxval"] = parab1.filter(regex='Tank???Slice???Max').apply(max, axis=1)
plt.plot(parab1.loc[parab1["cam"]==1,"Time"], parab1.max(parab1.loc[parab1["cam"]==1,parab1.filter(regex='Tank 1 Slice ? Max')]), label="Cam1")
plt.plot(parab1.loc[parab1["cam"]==2,"Time"], parab1.loc[parab1["cam"]==2,"Tank 2 Slice 1 Max"], label="Cam2")
plt.plot(parab1.loc[parab1["cam"]==3,"Time"], parab1.loc[parab1["cam"]==3,"Tank 3 Slice 1 Max"], label="Cam3")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2176/1145814878.py in <module>
# ----> 1 parab1["maxval"] = parab1.filter(regex='Tank???Slice???Max').apply(max, axis=1)
#       2 plt.plot(parab1.loc[parab1["cam"]==1,"Time"], parab1.max(parab1.loc[parab1["cam"]==1,parab1.filter(regex='Tank 1 Slice ? Max')]), label="Cam1")
#       3 plt.plot(parab1.loc[parab1["cam"]==2,"Time"], parab1.loc[parab1["cam"]==2,"Tank 2 Slice 1 Max"], label="Cam2")
#       4 plt.plot(parab1.loc[parab1["cam"]==3,"Time"], parab1.loc[parab1["cam"]==3,"Tank 3 Slice 1 Max"], label="Cam3")
#       5 plt.legend()
#
# NameError: name 'parab1' is not defined

# %%
plt.plot(df_c1["Time"])
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
pd.set_option("display.max_columns", None)

parab1.loc[parab1["cam"]==2]
# Out:
#        Frame       Time  Tank 1 Slice 1 Min  Tank 1 Slice 1 Max  \
# 10271      0   0.000000                 NaN                 NaN
# 10272      1   0.033333                 NaN                 NaN
# 10273      2   0.066667                 NaN                 NaN
# 10274      3   0.100000                 NaN                 NaN
# 10275      4   0.133333                 NaN                 NaN
# ...      ...        ...                 ...                 ...
# 10983    712  23.733333                 NaN                 NaN
# 10984    713  23.766667                 NaN                 NaN
# 10985    714  23.800000                 NaN                 NaN
# 10986    715  23.833333                 NaN                 NaN
# 10987    716  23.866667                 NaN                 NaN
#
#        Tank 1 Slice 2 Min  Tank 1 Slice 2 Max  Tank 1 Slice 3 Min  \
# 10271                 NaN                 NaN                 NaN
# 10272                 NaN                 NaN                 NaN
# 10273                 NaN                 NaN                 NaN
# 10274                 NaN                 NaN                 NaN
# 10275                 NaN                 NaN                 NaN
# ...                   ...                 ...                 ...
# 10983                 NaN                 NaN                 NaN
# 10984                 NaN                 NaN                 NaN
# 10985                 NaN                 NaN                 NaN
# 10986                 NaN                 NaN                 NaN
# 10987                 NaN                 NaN                 NaN
#
#        Tank 1 Slice 3 Max  Tank 1 Slice 4 Min  Tank 1 Slice 4 Max  \
# 10983            1.589788                 0.0            1.711859
# 10984            1.522199                 0.0            1.636896
# 10985            1.413646                 0.0            1.805665
# 10986            1.522199                 0.0            1.999012
# 10987            1.730497                 0.0            2.096096
#
#        Tank 2 Slice 7 Min  Tank 2 Slice 7 Max  Tank 2 Slice 8 Min  \
# 10271                 0.0            4.891845                 0.0
# 10272                 0.0            5.634511                 0.0
# 10273                 0.0            6.377177                 0.0
# 10274                 0.0            6.722089                 0.0
# 10275                 0.0            6.377177                 0.0
# ...                   ...                 ...                 ...
# 10983                 0.0            1.668848                 0.0
# 10984                 0.0            1.450922                 0.0
# 10985                 0.0            1.643450                 0.0
# 10986                 0.0            1.886773                 0.0
# 10987                 0.0            2.005566                 0.0
#
#        Tank 2 Slice 8 Max  Tank 2 Slice 9 Min  Tank 2 Slice 9 Max  \
# 10271            7.050615                 0.0            4.745197
# 10272            7.503260                 0.0            4.149999
# 10273            7.205456                 0.0            3.554801
# 10274            7.370948                 0.0            3.444610
# 10275            7.536440                 0.0            3.554801
# ...                   ...                 ...                 ...
# 10983            2.033422                 0.0            2.306647
# 10984            1.950676                 0.0            2.323442
# 10985            2.027687                 0.0            2.328972
# 10986            2.116168                 0.0            2.334502
# 10987            2.145661                 0.0            2.312177
#
#        Tank 2 Slice 10 Min  Tank 2 Slice 10 Max  Tank 2 Slice 11 Min  \
# 10271                  0.0             0.000000                  0.0
# 10272                  0.0             0.000000                  0.0
# 10273                  0.0             0.000000                  0.0
# 10274                  0.0             0.247828                  0.0
# 10275                  0.0             0.495657                  0.0
# ...                    ...                  ...                  ...
# 10983                  0.0             2.308951                  0.0
# 10984                  0.0             2.335219                  0.0
# 10985                  0.0             2.308951                  0.0
# 10986                  0.0             2.282684                  0.0
# 10987                  0.0             2.269473                  0.0
#
#        Tank 2 Slice 11 Max  Tank 2 Slice 12 Min  Tank 2 Slice 12 Max  \
# 10271             6.545946                  0.0             3.326225
# 10272             7.701113                  0.0             4.490404
# 10273             8.856280                  0.0             5.654583
# 10274             9.460080                  0.0             6.652041
# 10275            10.063880                  0.0             7.649499
# ...                    ...                  ...                  ...
# 10983             1.765521                  0.0             1.238732
# 10984             1.699980                  0.0             1.195311
# 10985             1.640993                  0.0             1.018349
# 10986             1.582005                  0.0             1.282153
# 10987             1.765316                  0.0             1.531006
#
#        Tank 2 Slice 13 Min  Tank 2 Slice 13 Max  Tank 2 Slice 14 Min  \
# 10271                  0.0             3.588391                  0.0
# 10272                  0.0             4.844328                  0.0
# 10273                  0.0             6.100265                  0.0
# 10274                  0.0             7.239456                  0.0
# 10275                  0.0             8.378647                  0.0
# ...                    ...                  ...                  ...
# 10983                  0.0             1.491476                  0.0
# 10984                  0.0             1.498440                  0.0
# 10985                  0.0             1.504175                  0.0
# 10986                  0.0             1.509910                  0.0
# 10987                  0.0             1.504175                  0.0
#
#        Tank 2 Slice 14 Max  Tank 3 Slice 1 Min  Tank 3 Slice 1 Max  \
# 10271             1.361622                 NaN                 NaN
# 10272             1.276521                 NaN                 NaN
# 10273             1.191420                 NaN                 NaN
# 10274             1.276521                 NaN                 NaN
# 10275             1.361622                 NaN                 NaN
# ...                    ...                 ...                 ...
# 10983             1.794196                 NaN                 NaN
# 10984             1.781906                 NaN                 NaN
# 10985             1.658607                 NaN                 NaN
# 10986             1.781906                 NaN                 NaN
# 10987             1.913194                 NaN                 NaN
#
#        Tank 3 Slice 2 Min  Tank 3 Slice 2 Max  Tank 3 Slice 3 Min  \
# 10271                 NaN                 NaN                 NaN
# 10272                 NaN                 NaN                 NaN
# 10273                 NaN                 NaN                 NaN
# 10274                 NaN                 NaN                 NaN
# 10275                 NaN                 NaN                 NaN
# ...                   ...                 ...                 ...
# 10983                 NaN                 NaN                 NaN
# 10984                 NaN                 NaN                 NaN
# 10985                 NaN                 NaN                 NaN
# 10986                 NaN                 NaN                 NaN
# 10987                 NaN                 NaN                 NaN
#
#        Tank 3 Slice 3 Max  Tank 3 Slice 4 Min  Tank 3 Slice 4 Max  \
# 10271                 NaN                 NaN                 NaN
# 10272                 NaN                 NaN                 NaN
# 10273                 NaN                 NaN                 NaN
# 10274                 NaN                 NaN                 NaN
# 10275                 NaN                 NaN                 NaN
# ...                   ...                 ...                 ...
# 10983                 NaN                 NaN                 NaN
# 10984                 NaN                 NaN                 NaN
# 10985                 NaN                 NaN                 NaN
# 10986                 NaN                 NaN                 NaN
# 10987                 NaN                 NaN                 NaN
#
#        Tank 3 Slice 5 Min  Tank 3 Slice 5 Max  Tank 3 Slice 6 Min  \
# 10271                 NaN                 NaN                 NaN
# 10272                 NaN                 NaN                 NaN
# 10273                 NaN                 NaN                 NaN
# 10274                 NaN                 NaN                 NaN
# 10275                 NaN                 NaN                 NaN
# ...                   ...                 ...                 ...
# 10983                 NaN                 NaN                 NaN
# 10984                 NaN                 NaN                 NaN
# 10985                 NaN                 NaN                 NaN
# 10986                 NaN                 NaN                 NaN
# 10987                 NaN                 NaN                 NaN
#
#        Tank 3 Slice 6 Max  Tank 3 Slice 7 Min  Tank 3 Slice 7 Max  \
# 10271                 NaN                 NaN                 NaN
# 10272                 NaN                 NaN                 NaN
# 10273                 NaN                 NaN                 NaN
# 10274                 NaN                 NaN                 NaN
# 10275                 NaN                 NaN                 NaN
# ...                   ...                 ...                 ...
# 10983                 NaN                 NaN                 NaN
# 10984                 NaN                 NaN                 NaN
# 10985                 NaN                 NaN                 NaN
# 10986                 NaN                 NaN                 NaN
# 10987                 NaN                 NaN                 NaN
#
#        Tank 3 Slice 8 Min  Tank 3 Slice 8 Max  Tank 3 Slice 9 Min  \
# 10271                 NaN                 NaN                 NaN
# 10272                 NaN                 NaN                 NaN
# 10273                 NaN                 NaN                 NaN
# 10274                 NaN                 NaN                 NaN
# 10275                 NaN                 NaN                 NaN
# ...                   ...                 ...                 ...
# 10983                 NaN                 NaN                 NaN
# 10984                 NaN                 NaN                 NaN
# 10985                 NaN                 NaN                 NaN
# 10986                 NaN                 NaN                 NaN
# 10987                 NaN                 NaN                 NaN
#
#        Tank 3 Slice 9 Max  Tank 3 Slice 10 Min  Tank 3 Slice 10 Max  \
# 10271                 NaN                  NaN                  NaN
# 10272                 NaN                  NaN                  NaN
# 10273                 NaN                  NaN                  NaN
# 10274                 NaN                  NaN                  NaN
# 10275                 NaN                  NaN                  NaN
# ...                   ...                  ...                  ...
# 10983                 NaN                  NaN                  NaN
# 10984                 NaN                  NaN                  NaN
# 10985                 NaN                  NaN                  NaN
# 10986                 NaN                  NaN                  NaN
# 10987                 NaN                  NaN                  NaN
#
#        Tank 3 Slice 11 Min  Tank 3 Slice 11 Max  Tank 3 Slice 12 Min  \
# 10271                  NaN                  NaN                  NaN
# 10272                  NaN                  NaN                  NaN
# 10273                  NaN                  NaN                  NaN
# 10274                  NaN                  NaN                  NaN
# 10275                  NaN                  NaN                  NaN
# ...                    ...                  ...                  ...
# 10983                  NaN                  NaN                  NaN
# 10984                  NaN                  NaN                  NaN
# 10985                  NaN                  NaN                  NaN
# 10986                  NaN                  NaN                  NaN
# 10987                  NaN                  NaN                  NaN
#
#        Tank 3 Slice 12 Max  Tank 3 Slice 13 Min  Tank 3 Slice 13 Max  \
# 10271                  NaN                  NaN                  NaN
# 10272                  NaN                  NaN                  NaN
# 10273                  NaN                  NaN                  NaN
# 10274                  NaN                  NaN                  NaN
# 10275                  NaN                  NaN                  NaN
# ...                    ...                  ...                  ...
# 10983                  NaN                  NaN                  NaN
# 10984                  NaN                  NaN                  NaN
# 10985                  NaN                  NaN                  NaN
# 10986                  NaN                  NaN                  NaN
# 10987                  NaN                  NaN                  NaN
#
#        Tank 3 Slice 14 Min  Tank 3 Slice 14 Max
# 10271                  NaN                  NaN
# 10272                  NaN                  NaN
# 10273                  NaN                  NaN
# 10274                  NaN                  NaN
# 10275                  NaN                  NaN
# ...                    ...                  ...
# 10983                  NaN                  NaN
# 10984                  NaN                  NaN
# 10985                  NaN                  NaN
# 10986                  NaN                  NaN
# 10987                  NaN                  NaN
#
# [717 rows x 88 columns]

# %%
parab1 = df_fc[df_fc["parab"].isin([1])]
plt.plot(parab1.loc[parab1["cam"]==1,"Time"], parab1.loc[parab1["cam"]==1,"Tank 1 Slice 1 Max"], label="Cam1")
plt.plot(parab1.loc[parab1["cam"]==2,"Time"], parab1.loc[parab1["cam"]==2,"Tank 2 Slice 1 Max"], label="Cam2")
plt.plot(parab1.loc[parab1["cam"]==3,"Time"], parab1.loc[parab1["cam"]==3,"Tank 3 Slice 1 Max"], label="Cam3")
plt.legend()

# %%
parab1 = df_fc[df_fc["parab"].isin([13])]
plt.plot(parab1.loc[parab1["cam"]==1,"Time"], parab1.loc[parab1["cam"]==1,"Tank 1 Slice 1 Max"], label="Cam1")
plt.plot(parab1.loc[parab1["cam"]==2,"Time"], parab1.loc[parab1["cam"]==2,"Tank 2 Slice 1 Max"], label="Cam2")
plt.plot(parab1.loc[parab1["cam"]==3,"Time"], parab1.loc[parab1["cam"]==3,"Tank 3 Slice 1 Max"], label="Cam3")
plt.legend()
